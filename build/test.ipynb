# %%
tokens = {"abc": "ABC", "def": "", "ghi": None}
tokens
# Out:
# {'abc': 'ABC', 'def': '', 'ghi': None}

# %%
token_auto_fill = "gef"
tokens.get("abc", token_auto_fill), tokens.get("def", token_auto_fill), tokens.get("ghi", token_auto_fill)
# Out:
# ('ABC', '', None)
